# %% [markdown]
# <a href="https://colab.research.google.com/github/Tariquzzaman-faisal/hatespeech/blob/main/encoding_generator_gpu_accelerated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mounting to drive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Text Preprocessing

# %%
# !pip install –upgrade setuptools
# !pip install git+https://github.com/csebuetnlp/normalizer
# !pip install pandas transformers torch
# Out:
# ERROR: Invalid requirement: '–upgrade'
# Collecting git+https://github.com/csebuetnlp/normalizer
#   Cloning https://github.com/csebuetnlp/normalizer to /tmp/pip-req-build-yudgype9
#   Running command git clone --filter=blob:none --quiet https://github.com/csebuetnlp/normalizer /tmp/pip-req-build-yudgype9
#   Resolved https://github.com/csebuetnlp/normalizer to commit d80c3c484e1b80268f2b2dfaf7557fe65e34f321
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from normalizer==0.0.1) (2022.10.31)
# Collecting emoji==1.4.2 (from normalizer==0.0.1)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy==6.0.3 (from normalizer==0.0.1)
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy==6.0.3->normalizer==0.0.1) (0.2.6)
# Building wheels for collected packages: normalizer, emoji, ftfy
#   Building wheel for normalizer (setup.py) ... done
#   Created wheel for normalizer: filename=normalizer-0.0.1-py3-none-any.whl size=6860 sha256=f081dca7f61ac3fedbe56b086e783240197b249207074c91bd683715641b1512
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zo4tmn8n/wheels/2e/79/9c/cd96d490298305d51d2da11484bb2c25fd1f759a6906708282
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186456 sha256=c68795258dd4da9a6290a6cad63922353fb219590be741ae859b5ace865f12dc
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41931 sha256=c1075adc7da7c6e9c737c62b57a046602393b97bab90887f197fc1afcca5cd10
#   Stored in directory: /root/.cache/pip/wheels/92/8e/16/c1e4d4d65685d71085e4e27b44d6ed880b0559474c9ee4ff66
# Successfully built normalizer emoji ftfy
# Installing collected packages: emoji, ftfy, normalizer
# Successfully installed emoji-1.4.2 ftfy-6.0.3 normalizer-0.0.1
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting transformers
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.31.0

# %%
import re
from normalizer import normalize

def remove_html_tags(text):
    clean_text = re.sub(r'<.*?>', '', text)
    return clean_text

def remove_links(text):
    clean_text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    return clean_text

# def remove_special_characters(text):
#     clean_text = re.sub(r'[^\w\s০-৯\s]', '', text)  # Include Bangla digits (০-৯)
#     return clean_text

def remove_hashtags(text):
    clean_text = re.sub(r'#', '', text)
    return clean_text

def remove_emojis(text):
    # Replace emojis and emoticons with an empty string
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F700-\U0001F77F"  # alchemical symbols
        u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA00-\U0001FA6F"  # Chess Symbols
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U0001F000-\U0001F0FF"  # Mahjong Tiles
        u"\U0001F200-\U0001F2FF"  # Enclosed Ideographic Supplement
        u"\U0001F400-\U0001F4FF"  # Miscellaneous Symbols and Pictographs
        u"\U0001F500-\U0001F53F"  # Emoticons (Emoji)
        u"\U0001F540-\U0001F543"  # Transport and Map Symbols
        u"\U0001F550-\U0001F567"  # Alchemical Symbols
        u"\U0001F680-\U0001F6C5"  # Transport and Map Symbols Extended
        u"\U0001F700-\U0001F773"  # Alchemical Symbols Extended
        u"\U0001F780-\U0001F7D4"  # Geometric Shapes Extended-A
        u"\U0001F800-\U0001F80B"  # Supplemental Arrows-C Extended
        u"\U0001F810-\U0001F847"  # Supplemental Symbols and Pictographs Extended-B
        u"\U0001F850-\U0001F859"  # Symbols and Pictographs Extended-C
        u"\U0001F860-\U0001F887"  # Enclosed Ideographic Supplement Extended-A
        u"\U0001F890-\U0001F8AD"  # Enclosed Ideographic Supplement Extended-B
        u"\U0001F900-\U0001F90B"  # Supplemental Symbols and Pictographs Extended-C
        u"\U0001F90D-\U0001F971"  # Emoji Additional Information
        u"\U0001F973-\U0001F97A"  # Emoji Additional Information-Supplement
        u"\U0001F97C-\U0001F9A2"  # Emoji Additional Information-Supplement
        u"\U0001F9A5-\U0001F9AA"  # Emoji Additional Information-Supplement
        u"\U0001F9AE-\U0001F9CA"  # Emoji Additional Information-Supplement
        u"\U0001F9CD-\U0001F9FF"  # Emoji Additional Information-Supplement
        u"\U0001FA00-\U0001FA6D"  # Emoji Additional Information-Supplement
        u"\U0001FA70-\U0001FAD6"  # Emoji Additional Information-Supplement
        u"\U0001F600-\U0001F9FF"  # Miscellaneous Symbols and Pictographs
                           "]", flags=re.UNICODE)
    clean_text = emoji_pattern.sub(r'', text)
    return clean_text

# def remove_duplicates(text):
#     # Remove consecutive duplicate words
#     words = text.split()
#     unique_words = []
#     for word in words:
#         if word not in unique_words:
#             unique_words.append(word)
#     clean_text = ' '.join(unique_words)
#     return clean_text

# def remove_infrequent_words(text, min_df=5):
#     # Remove tokens with a document frequency less than min_df
#     words = text.split()
#     word_freq = {}
#     for word in words:
#         word_freq[word] = word_freq.get(word, 0) + 1
#     frequent_words = [word for word, freq in word_freq.items() if freq >= min_df]
#     clean_text = ' '.join(frequent_words)
#     return clean_text


def remove_extra_whitespaces(input_string):
    return re.sub(r'\s+', ' ', input_string).strip()

def preprocess_bangla_text(text):
    text = remove_html_tags(text)
    text = remove_links(text)
    # text = remove_special_characters(text)
    text = remove_hashtags(text)
    text = remove_emojis(text)
    # text = remove_duplicates(text)
    # text = remove_infrequent_words(text)
    text = remove_extra_whitespaces(text)
    return text

# Example usage
input_text = """
    <h1>বাংলা টেক্সট স্যাম্পল</h1>
    <p>এই টেক্সটে আমরা সাধারণ বাংলা বাক্যাংশ এবং পোস্টের জন্য এইচটিএমএল ট্যাগ, লিঙ্ক, হ্যাশট্যাগ এবং ইমোজি ব্যবহার করব।</p>

    <p>এই লিংকে ক্লিক করুন: <a href="https://www.example.com">সাম্পল লিঙ্ক</a></p>

    <h2>হ্যাশট্যাগ:</h2>
    <p>সাম্পল হ্যাশট্যাগ গুলির মধ্যে থাকছে: #বাংলা #টেক্সট #এইচটিএমএল #লিঙ্ক #ইমোজি</p>

    <h2>ইমোজি:</h2>
    <p>আমরা এই বাংলা পোস্টের জন্য কিছু ইমোজি ব্যবহার করব। 😊👍🎉💻📚</p>
    """
preprocessed_text = preprocess_bangla_text(input_text)
print(preprocessed_text)
# Out:
# বাংলা টেক্সট স্যাম্পল এই টেক্সটে আমরা সাধারণ বাংলা বাক্যাংশ এবং পোস্টের জন্য এইচটিএমএল ট্যাগ, লিঙ্ক, হ্যাশট্যাগ এবং ইমোজি ব্যবহার করব। এই লিংকে ক্লিক করুন: সাম্পল লিঙ্ক হ্যাশট্যাগ: সাম্পল হ্যাশট্যাগ গুলির মধ্যে থাকছে: বাংলা টেক্সট এইচটিএমএল লিঙ্ক ইমোজি ইমোজি: আমরা এই বাংলা পোস্টের জন্য কিছু ইমোজি ব্যবহার করব।

# %%
import pandas as pd
import torch
from transformers import BertTokenizer
import re

df = pd.read_csv("/content/drive/MyDrive/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla/bengali_hate_v2.0.csv")
# Extract text and label columns
texts = df["text"].tolist()
labels = df["target"].tolist()

print(f'No of texts: {len(texts)}\nNo of labels: {len(labels)}')
# Out:
# No of texts: 5698
# No of labels: 5698

# %%
cleaned_texts = []
for text in texts:
    cleaned_text = preprocess_bangla_text(text)
    cleaned_texts.append(cleaned_text)

# %%
cleaned_texts[:5]
# Out:
# ['বৌদির দুধ দেকে তো আমার ই চোখ ঠিক ছিলো না - পোলাপান এর চোখ কিভাবে ঠিক থাকবে!',
#  'এই সরকার কে যারা নির্লজ্জের মত সাপোর্ট দিয়েছে বছরের পর বছর, তাদের আরো এমন রাস্তায় রাস্তায় কাঁদতে হবে',
#  'পিলখানা হত্যাকান্ড বাংলাদেশের প্রতিরক্ষা ব্যবস্থা ধ্বংসের জন্য ভারতের প্রত্যক্ষ সহযোগিতায় এই হত্যাকা- ঘটানো হয়েছিল',
#  'ভারতের অর্থনীতি নিয়ে আপনাদের ভাবতে হবে না। ভারতের অর্থনীতি নিয়ে ভারত সরকার আছে। আদার বেপারী জাহাজের খোঁজ নিয়ে লাভ নাই।',
#  'খানকির পুলা মালায়নদের মেরে সাফা করে ফেল']

# %% [markdown]
# # Creating BanglaBERT Embeddings

# %%
from transformers import AutoModelForPreTraining, AutoTokenizer
from normalizer import normalize
import torch

model = AutoModelForPreTraining.from_pretrained("csebuetnlp/banglabert")
tokenizer = AutoTokenizer.from_pretrained("csebuetnlp/banglabert")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/586 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/528k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
import torch

if torch.cuda.is_available():
    device = torch.device('cuda')
    print('GPU is available!')
else:
    device = torch.device('cpu')
    print('No GPU found, using CPU.')
# Out:
# GPU is available!

# %%
import numpy as np
import torch

def get_bert_embeddings(text, model, tokenizer):
    text = normalize(text)
    max_length = 128
    inputs = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_tensors='pt'
    )

    # Check if CUDA (GPU) is available and set the device accordingly
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Move inputs to the device (CPU or GPU)
    inputs = {key: value.to(device) for key, value in inputs.items()}

    # Generate BERT embeddings on the device
    with torch.no_grad():
        model.eval()
        model.to(device)
        outputs = model(**inputs)
        embeddings = outputs.logits  # Get embeddings from the last hidden layer

    return embeddings.to('cpu')  # Move embeddings back to the CPU for further processing

# Example usage:
# Assuming you have 'model' and 'tokenizer' objects already initialized, you can use the function as follows:
# bert_embeddings = get_bert_embeddings("Your input text", model, tokenizer)

# %%
bertEmbeddings = []

# Loop through each cleaned text and get BERT embeddings
for text in cleaned_texts:
    # Get the BERT embeddings for each cleaned text
    embedding = get_bert_embeddings(text, model, tokenizer)
    flattened_array = embedding.flatten().numpy()
    bertEmbeddings.append(flattened_array)
    # Alternatively, you can directly append the original 2D embedding array
    # bertEmbeddings.append(embedding.numpy())

# Convert the list of BERT embeddings to a NumPy array
bertEmbeddings = np.array(bertEmbeddings)

# %%
print(f'Embeddings: {len(bertEmbeddings)}')
print(f'Targets: {len(labels)}')
# Out:
# Embeddings: 5698
# Targets: 5698

# %%
# print(bertEmbeddings)

# %%
# import csv

# data = zip(bertEmbeddings, labels)

# # Specify the CSV file path
# csv_file_path = "/content/drive/MyDrive/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla/embedded.csv"

# # Write the data to the CSV file
# with open(csv_file_path, mode="w", newline="", encoding="utf-8") as file:
#     writer = csv.writer(file)
#     writer.writerow(["text", "label"])  # Write the header
#     writer.writerows(data)  # Write the data rows

# %%
# Assuming you have `bertEmbeddings` and `labels` as NumPy arrays
import csv
data = np.column_stack((bertEmbeddings, labels))  # Combine the arrays horizontally

# Specify the CSV file path
csv_file_path = "/content/drive/MyDrive/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla/embedded2.csv"

with open(csv_file_path, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["text", "label"])  # Write the header
    writer.writerows(data)  # Write the data rows

# %%
import csv
import numpy as np

# Specify the CSV file path
csv_file_path = "/content/drive/MyDrive/Research/Shared Task/Violence Inciting Text Detection (VITD) Bangla/embedded2.csv"

# Read the data from the CSV file
data = np.genfromtxt(csv_file_path, delimiter=',', skip_header=1)

# Split the data into `bertEmbeddings` and `labels` arrays
bertEmbeddings = data[:, :-1]
labels = data[:, -1].astype(int)

# %%
print(bertEmbeddings)
# Out:
# [[-13.00299263  -0.73461741  -0.57270575 ...  -1.18679011   4.70789433
#   -13.14398575]
#  [-12.77867699  -2.68920493  -3.35125685 ...  -2.41241527   5.1453104
#   -12.67943573]
#  [-14.3321743   -7.83530235  -3.7488277  ...  -1.73290098  -3.04261637
#   -14.16944313]
#  ...
#  [-15.28562164  -2.84474206  -2.16434884 ...   0.17359121   4.78863382
#    -0.67929214]
#  [-12.23878384  -3.43063712  -7.23090363 ...   0.35684556   1.14516771
#   -12.33890343]
#  [-13.61747742  -4.03414202  -3.02905583 ...  -2.24742937  -0.34948486
#   -13.41543579]]

# %%
print(labels)
# Out:
# [0 1 3 ... 0 0 1]

# %%
len(tokenizer)
